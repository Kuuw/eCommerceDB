-- %% [markdown]
-- # [dbo].[Address]

-- %%
USE [ecommerceDB]
GO

-- %%
/****** Object:  Table [dbo].[Address]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Address](
	[AddressId] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [int] NOT NULL,
	[CountryId] [int] NOT NULL,
	[FirstName] [nvarchar](127) NOT NULL,
	[LastName] [nvarchar](127) NOT NULL,
	[AddressLine1] [nvarchar](254) NOT NULL,
	[AddressLine2] [nvarchar](254) NULL,
	[PostalCode] [nvarchar](63) NOT NULL,
	[Telephone] [nvarchar](127) NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[UpdatedAt] [datetime] NOT NULL,
 CONSTRAINT [PK__Address__091C2AFBB08AA636] PRIMARY KEY CLUSTERED 
(
	[AddressId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CartItem]

-- %%
/****** Object:  Table [dbo].[CartItem]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CartItem](
	[UserId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UserId] ASC,
	[ProductId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Category]

-- %%
/****** Object:  Table [dbo].[Category]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Category](
	[CategoryId] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](127) NOT NULL,
	[Description] [nvarchar](127) NULL,
 CONSTRAINT [PK__Category__19093A0B5124EBED] PRIMARY KEY CLUSTERED 
(
	[CategoryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Country]

-- %%
/****** Object:  Table [dbo].[Country]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Country](
	[CountryId] [int] IDENTITY(1,1) NOT NULL,
	[CountryName] [nvarchar](127) NOT NULL,
	[CountryPhoneCode] [int] NOT NULL,
	[UpdatedAt] [datetime] NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
 CONSTRAINT [PK__Country__10D1609F426CB050] PRIMARY KEY CLUSTERED 
(
	[CountryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Order]

-- %%
/****** Object:  Table [dbo].[Order]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Order](
	[OrderId] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [int] NOT NULL,
	[AddressId] [int] NOT NULL,
	[ShipmentCompanyId] [int] NULL,
	[ShipmentTrack] [nvarchar](127) NULL,
	[CreatedAt] [datetime] NOT NULL,
	[ShippedAt] [datetime] NULL,
 CONSTRAINT [PK__Order__C3905BCF6193CD57] PRIMARY KEY CLUSTERED 
(
	[OrderId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderItem]

-- %%
/****** Object:  Table [dbo].[OrderItem]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderItem](
	[OrderId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
	[UnitPrice] [float] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[OrderId] ASC,
	[ProductId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[ProductId] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](127) NOT NULL,
	[Description] [nvarchar](127) NULL,
	[CategoryId] [int] NOT NULL,
	[UnitPrice] [float] NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[UpdatedAt] [datetime] NOT NULL,
 CONSTRAINT [PK__Product__B40CC6CD675797C6] PRIMARY KEY CLUSTERED 
(
	[ProductId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductImage]

-- %%
/****** Object:  Table [dbo].[ProductImage]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductImage](
	[ProductImageId] [uniqueidentifier] NOT NULL,
	[ProductId] [int] NOT NULL,
	[ImagePath] [nvarchar](254) NOT NULL,
	[ImageExtension] [nvarchar](15) NOT NULL,
 CONSTRAINT [PK__ProductI__C27DB42B5C12ED3D] PRIMARY KEY CLUSTERED 
(
	[ProductImageId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductStock]

-- %%
/****** Object:  Table [dbo].[ProductStock]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductStock](
	[ProductId] [int] NOT NULL,
	[Stock] [int] NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[UpdatedAt] [datetime] NOT NULL,
 CONSTRAINT [PK__ProductS__B40CC6CDDC8696C8] PRIMARY KEY CLUSTERED 
(
	[ProductId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ShipmentCompany]

-- %%
/****** Object:  Table [dbo].[ShipmentCompany]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ShipmentCompany](
	[ShipmentCompanyId] [int] IDENTITY(1,1) NOT NULL,
	[CompanyName] [nvarchar](127) NOT NULL,
	[CompanySite] [nvarchar](127) NULL,
	[CompanyLogoUrl] [nvarchar](127) NULL,
 CONSTRAINT [PK__Shipment__A9F5E8AFC589C062] PRIMARY KEY CLUSTERED 
(
	[ShipmentCompanyId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 3.01.2025 13:02:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[UserId] [int] IDENTITY(1,1) NOT NULL,
	[Email] [nvarchar](254) NOT NULL,
	[PasswordHash] [nvarchar](63) NOT NULL,
	[FirstName] [nvarchar](127) NOT NULL,
	[LastName] [nvarchar](127) NOT NULL,
	[Telephone] [nvarchar](127) NULL,
	[Role] [nvarchar](63) NOT NULL,
	[CreatedAt] [datetime] NOT NULL,
	[UpdatedAt] [datetime] NOT NULL,
 CONSTRAINT [PK__User__1788CC4CB3DE15CF] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ__User__A9D10534CAD6D1B1] UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Address__Created__2E1BDC42]

-- %%
ALTER TABLE [dbo].[Address] ADD  CONSTRAINT [DF__Address__Created__2E1BDC42]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Address__Updated__2F10007B]

-- %%
ALTER TABLE [dbo].[Address] ADD  CONSTRAINT [DF__Address__Updated__2F10007B]  DEFAULT (getdate()) FOR [UpdatedAt]
GO

-- %% [markdown]
-- # [DF__Order__CreatedAt__45F365D3]

-- %%
ALTER TABLE [dbo].[Order] ADD  CONSTRAINT [DF__Order__CreatedAt__45F365D3]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Product__Created__33D4B598]

-- %%
ALTER TABLE [dbo].[Product] ADD  CONSTRAINT [DF__Product__Created__33D4B598]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Product__Updated__34C8D9D1]

-- %%
ALTER TABLE [dbo].[Product] ADD  CONSTRAINT [DF__Product__Updated__34C8D9D1]  DEFAULT (getdate()) FOR [UpdatedAt]
GO

-- %% [markdown]
-- # [DF__ProductIm__Produ__2CBDA3B5]

-- %%
ALTER TABLE [dbo].[ProductImage] ADD  CONSTRAINT [DF__ProductIm__Produ__2CBDA3B5]  DEFAULT (newid()) FOR [ProductImageId]
GO

-- %% [markdown]
-- # [DF__ProductSt__Creat__38996AB5]

-- %%
ALTER TABLE [dbo].[ProductStock] ADD  CONSTRAINT [DF__ProductSt__Creat__38996AB5]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__ProductSt__Updat__398D8EEE]

-- %%
ALTER TABLE [dbo].[ProductStock] ADD  CONSTRAINT [DF__ProductSt__Updat__398D8EEE]  DEFAULT (getdate()) FOR [UpdatedAt]
GO

-- %% [markdown]
-- # [DF__User__IsAdmin__276EDEB3]

-- %%
ALTER TABLE [dbo].[User] ADD  CONSTRAINT [DF__User__IsAdmin__276EDEB3]  DEFAULT ((0)) FOR [Role]
GO

-- %% [markdown]
-- # [DF__User__CreatedAt__286302EC]

-- %%
ALTER TABLE [dbo].[User] ADD  CONSTRAINT [DF__User__CreatedAt__286302EC]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__User__UpdatedAt__29572725]

-- %%
ALTER TABLE [dbo].[User] ADD  CONSTRAINT [DF__User__UpdatedAt__29572725]  DEFAULT (getdate()) FOR [UpdatedAt]
GO

-- %% [markdown]
-- # [FK__Address__Country__2D27B809]

-- %%
ALTER TABLE [dbo].[Address]  WITH CHECK ADD  CONSTRAINT [FK__Address__Country__2D27B809] FOREIGN KEY([CountryId])
REFERENCES [dbo].[Country] ([CountryId])
GO
ALTER TABLE [dbo].[Address] CHECK CONSTRAINT [FK__Address__Country__2D27B809]
GO

-- %% [markdown]
-- # [FK__Address__UserId__2C3393D0]

-- %%
ALTER TABLE [dbo].[Address]  WITH CHECK ADD  CONSTRAINT [FK__Address__UserId__2C3393D0] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([UserId])
GO
ALTER TABLE [dbo].[Address] CHECK CONSTRAINT [FK__Address__UserId__2C3393D0]
GO

-- %% [markdown]
-- # [FK__CartItem__Produc__403A8C7D]

-- %%
ALTER TABLE [dbo].[CartItem]  WITH CHECK ADD  CONSTRAINT [FK__CartItem__Produc__403A8C7D] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Product] ([ProductId])
GO
ALTER TABLE [dbo].[CartItem] CHECK CONSTRAINT [FK__CartItem__Produc__403A8C7D]
GO

-- %% [markdown]
-- # [FK__CartItem__UserId__3F466844]

-- %%
ALTER TABLE [dbo].[CartItem]  WITH CHECK ADD  CONSTRAINT [FK__CartItem__UserId__3F466844] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([UserId])
GO
ALTER TABLE [dbo].[CartItem] CHECK CONSTRAINT [FK__CartItem__UserId__3F466844]
GO

-- %% [markdown]
-- # [FK__Order__AddressId__440B1D61]

-- %%
ALTER TABLE [dbo].[Order]  WITH CHECK ADD  CONSTRAINT [FK__Order__AddressId__440B1D61] FOREIGN KEY([AddressId])
REFERENCES [dbo].[Address] ([AddressId])
GO
ALTER TABLE [dbo].[Order] CHECK CONSTRAINT [FK__Order__AddressId__440B1D61]
GO

-- %% [markdown]
-- # [FK__Order__ShipmentC__44FF419A]

-- %%
ALTER TABLE [dbo].[Order]  WITH CHECK ADD  CONSTRAINT [FK__Order__ShipmentC__44FF419A] FOREIGN KEY([ShipmentCompanyId])
REFERENCES [dbo].[ShipmentCompany] ([ShipmentCompanyId])
GO
ALTER TABLE [dbo].[Order] CHECK CONSTRAINT [FK__Order__ShipmentC__44FF419A]
GO

-- %% [markdown]
-- # [FK__Order__UserId__4316F928]

-- %%
ALTER TABLE [dbo].[Order]  WITH CHECK ADD  CONSTRAINT [FK__Order__UserId__4316F928] FOREIGN KEY([UserId])
REFERENCES [dbo].[User] ([UserId])
GO
ALTER TABLE [dbo].[Order] CHECK CONSTRAINT [FK__Order__UserId__4316F928]
GO

-- %% [markdown]
-- # [FK__OrderItem__Order__48CFD27E]

-- %%
ALTER TABLE [dbo].[OrderItem]  WITH CHECK ADD  CONSTRAINT [FK__OrderItem__Order__48CFD27E] FOREIGN KEY([OrderId])
REFERENCES [dbo].[Order] ([OrderId])
GO
ALTER TABLE [dbo].[OrderItem] CHECK CONSTRAINT [FK__OrderItem__Order__48CFD27E]
GO

-- %% [markdown]
-- # [FK__OrderItem__Produ__49C3F6B7]

-- %%
ALTER TABLE [dbo].[OrderItem]  WITH CHECK ADD  CONSTRAINT [FK__OrderItem__Produ__49C3F6B7] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Product] ([ProductId])
GO
ALTER TABLE [dbo].[OrderItem] CHECK CONSTRAINT [FK__OrderItem__Produ__49C3F6B7]
GO

-- %% [markdown]
-- # [FK_Product_Category]

-- %%
ALTER TABLE [dbo].[Product]  WITH CHECK ADD  CONSTRAINT [FK_Product_Category] FOREIGN KEY([CategoryId])
REFERENCES [dbo].[Category] ([CategoryId])
GO
ALTER TABLE [dbo].[Product] CHECK CONSTRAINT [FK_Product_Category]
GO

-- %% [markdown]
-- # [FK__ProductIm__Produ__3C69FB99]

-- %%
ALTER TABLE [dbo].[ProductImage]  WITH CHECK ADD  CONSTRAINT [FK__ProductIm__Produ__3C69FB99] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Product] ([ProductId])
GO
ALTER TABLE [dbo].[ProductImage] CHECK CONSTRAINT [FK__ProductIm__Produ__3C69FB99]
GO

-- %% [markdown]
-- # [FK__ProductSt__Produ__37A5467C]

-- %%
ALTER TABLE [dbo].[ProductStock]  WITH CHECK ADD  CONSTRAINT [FK__ProductSt__Produ__37A5467C] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Product] ([ProductId])
GO
ALTER TABLE [dbo].[ProductStock] CHECK CONSTRAINT [FK__ProductSt__Produ__37A5467C]
GO
